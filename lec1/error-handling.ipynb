# %% [markdown]
# # エラーハンドリングの基礎

# %%
x = 1
y = 0

# %%
# 0で割っているのでエラーが起きる
x / y
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x / y
#
# ZeroDivisionError: division by zero

# %%
try:
    result = x / y
except ZeroDivisionError as e:
    result = None
    print("エラーが発生しました:", e)
    print("0で割ることはできません。結果をNoneに設定します。")

print("結果:", result)
# Out:
# エラーが発生しました: division by zero
# 0で割ることはできません。結果をNoneに設定します。
# 結果: None

# %% [markdown]
# ## 複数のエラーが発生する可能性がある場合

# %%
try:
    result = x / z
except ZeroDivisionError as e:
    result = None
    print("エラーが発生しました:", e)
    print("0で割ることはできません。結果をNoneに設定します。")
except NameError as e:
    result = None
    print("エラーが発生しました:", e)
    print("未定義の変数が使用されました。結果をNoneに設定します。")

print("結果:", result)
# Out:
# エラーが発生しました: name 'z' is not defined
# 未定義の変数が使用されました。結果をNoneに設定します。
# 結果: None

# %% [markdown]
# ## エラーが発生しなかった場合にのみ実行したい処理がある場合

# %%
z = 3

try:
    result = x / z
except ZeroDivisionError as e:
    result = None
    print("エラーが発生しました:", e)
    print("0で割ることはできません。結果をNoneに設定します。")
except NameError as e:
    result = None
    print("エラーが発生しました:", e)
    print("未定義の変数が使用されました。結果をNoneに設定します。")
else:
    #tryブロック内でエラーが発生しなかった場合に実行される
    print("エラーは発生しませんでした。計算は正常に完了しました。")

print("結果:", result)
# Out:
# エラーは発生しませんでした。計算は正常に完了しました。
# 結果: 0.3333333333333333

# %% [markdown]
# ## エラーの発生の有無にかかわらず実行したい処理がある場合

# %%
z = 0

try:
    result = x / z
except ZeroDivisionError as e:
    result = None
    print("エラーが発生しました:", e)
    print("0で割ることはできません。結果をNoneに設定します。")
except NameError as e:
    result = None
    print("エラーが発生しました:", e)
    print("未定義の変数が使用されました。結果をNoneに設定します。")
else:
    #tryブロック内でエラーが発生しなかった場合に実行される
    print("エラーは発生しませんでした。計算結果を表示します。")
finally:
    #エラーの発生の有無にかかわらず実行される
    print("計算処理が終了しました。")

print("結果:", result)
# Out:
# エラーが発生しました: division by zero
# 0で割ることはできません。結果をNoneに設定します。
# 計算処理が終了しました。
# 結果: None

# %% [markdown]
# ## システム終了以外の以外の全てのエラーをハンドリングしたい場合

# %%
x = 1
y = 0
z = 3

try:
    x / y
except Exception as e:
    result = None
    print("エラーが発生しました:", e)
    print("エラーオブジェクト",type(e))
    print("計算を完了できませんでした。結果をNoneに設定します。")
else:
    print("計算は正常に完了しました。")
finally:
    print("計算処理が終了しました。")

print("結果:", result)
# Out:
# エラーが発生しました: division by zero
# エラーオブジェクト <class 'ZeroDivisionError'>
# 計算を完了できませんでした。結果をNoneに設定します。
# 計算処理が終了しました。
# 結果: None

# %% [markdown]
# ## Webスクレイピングでのエラー処理

# %%
import requests

# %%
url = 'https://www.musashino-u.ac.jp/invalid-page'
responce = requests.get(url)
print(f"ステータスコード:{responce.status_code}")

# ステータスコードが200以外の場合に例外を発生させる
responce.raise_for_status()
# Out:
# ステータスコード:404
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       3 print(f"ステータスコード:{responce.status_code}")
#       5 # ステータスコードが200以外の場合に例外を発生させる
# ----> 6 responce.raise_for_status()
#
# File ~/Lecture/DS-programming2/.venv/lib/python3.12/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://www.musashino-u.ac.jp/invalid-page

# %%
url = 'https://www.musashino-u.ac.jp/invalid-page'

try:
    responce = requests.get(url)
    responce.raise_for_status()  # ステータスコードが200以外の場合にHTTPErrorを発生させる
except requests.exceptions.HTTPError as e:
    print("HTTPエラーが発生しました:", e)
else:
    print("正常にページにアクセスできました。")
finally:
    print("Webスクレイピング処理が終了しました。")
# Out:
# HTTPエラーが発生しました: 404 Client Error: Not Found for url: https://www.musashino-u.ac.jp/invalid-page
# Webスクレイピング処理が終了しました。
